# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
print(f"Spark Version: {spark.version}")
# Out:
# Spark Version: 3.5.0

# %%
# !pwd
# Out:
# /home/jovyan

# %%
# !ls -F
# Out:
# test_arquitectura.ipynb  work/
